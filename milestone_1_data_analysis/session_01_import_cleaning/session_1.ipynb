# %% [markdown]
# # Session 1: Data Import & Cleaning
#
# This notebook covers data import, cleaning, and quality assessment for the NSMES1988 healthcare dataset.

# %%
# Import libraries
import pandas as pd
import numpy as np

# TODO: Add your data import and cleaning code here
